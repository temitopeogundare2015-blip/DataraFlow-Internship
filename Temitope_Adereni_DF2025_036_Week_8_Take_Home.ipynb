# %% [markdown]
# ## Provide Notebook-1 Tasks Solutions below (Execute them)

# %%
import pandas as pd

# %%
headings = ['Country name', 'Life expectancy (years)']
table = [
  ['Hong Kong', 85],
  ['Australia', 83],
  ['Singapore', 83],
  ['United States', 79],
  ['Brazil', 75]
]
life = pd.DataFrame(columns=headings, data=table)
print(life)
# Out:
#     Country name  Life expectancy (years)
# 0      Hong Kong                       85
# 1      Australia                       83
# 2      Singapore                       83
# 3  United States                       79
# 4         Brazil                       75

# %%
headings = ['Country name', 'GDP (US$)']
table = [
  ['Hong Kong', 500000000000.9],
  ['Australia', 16768100000000.0],
  ['Singapore', 9240270452047.0],
  ['United States', 2245673032353.8],
  ['Brazil', 366057913367.1]
]
gdp = pd.DataFrame(columns=headings, data=table)
print(gdp)
# Out:
#     Country name     GDP (US$)
# 0      Hong Kong  5.000000e+11
# 1      Australia  1.676810e+13
# 2      Singapore  9.240270e+12
# 3  United States  2.245673e+12
# 4         Brazil  3.660579e+11

# %%
def roundToMillions (value):
    return round(value / 1000000)

# %%
def usdToGBP (usd):
    return usd / 1.564768

# %%
gdp['Country name'] = gdp['Country name']
gdp['GDP (£m)'] = gdp['GDP (US$)'].apply(usdToGBP).apply(roundToMillions)
gdp['GDP (US$)'].apply(roundToMillions).apply(usdToGBP).apply(round)
headings = ['Country name', 'GDP (£m)']
gdp = gdp[headings]
print(gdp)
# Out:
#     Country name  GDP (£m)
# 0      Hong Kong    319536
# 1      Australia  10716029
# 2      Singapore   5905202
# 3  United States   1435148
# 4         Brazil    233937

# %%
pd.merge(gdp, life, on='Country name', how='left')
# Out:
#     Country name  GDP (£m)  Life expectancy (years)
# 0      Hong Kong    319536                       85
# 1      Australia  10716029                       83
# 2      Singapore   5905202                       83
# 3  United States   1435148                       79
# 4         Brazil    233937                       75

# %%
pd.merge(gdp, life, on='Country name', how='right')
# Out:
#     Country name  GDP (£m)  Life expectancy (years)
# 0      Hong Kong    319536                       85
# 1      Australia  10716029                       83
# 2      Singapore   5905202                       83
# 3  United States   1435148                       79
# 4         Brazil    233937                       75

# %%
pd.merge(gdp, life, on='Country name', how='outer')
# Out:
#     Country name  GDP (£m)  Life expectancy (years)
# 0      Australia  10716029                       83
# 1         Brazil    233937                       75
# 2      Hong Kong    319536                       85
# 3      Singapore   5905202                       83
# 4  United States   1435148                       79

# %%
gdpVsLife = pd.merge(gdp, life, on='Country name', how='inner')
gdpVsLife
# Out:
#     Country name  GDP (£m)  Life expectancy (years)
# 0      Hong Kong    319536                       85
# 1      Australia  10716029                       83
# 2      Singapore   5905202                       83
# 3  United States   1435148                       79
# 4         Brazil    233937                       75

# %% [markdown]
# ## Provide Notebook-2 Tasks Solutions below (Execute them)

# %%
POP_INDICATOR = 'SP.POP.TOTL'
popReset = pd.read_csv('WB POP 2013.csv')

# %%
popReset.head()
# Out:
#                                    country  year   SP.POP.TOTL
# 0                               Arab World  2013  3.770967e+08
# 1                   Caribbean small states  2013  6.975819e+06
# 2           Central Europe and the Baltics  2013  1.037137e+08
# 3  East Asia & Pacific (all income levels)  2013  2.248867e+09
# 4    East Asia & Pacific (developing only)  2013  2.006073e+09

# %%
popReset[0:3]
# Out:
#                           country  year  SP.POP.TOTL
# 0                      Arab World  2013  377096710.0
# 1          Caribbean small states  2013    6975819.0
# 2  Central Europe and the Baltics  2013  103713726.0

# %%
popReset[240:]
# Out:
#                    country  year  SP.POP.TOTL
# 240                Vanuatu  2013     253165.0
# 241          Venezuela, RB  2013   30276045.0
# 242                Vietnam  2013   89708900.0
# 243  Virgin Islands (U.S.)  2013     104737.0
# 244     West Bank and Gaza  2013    4169506.0
# 245            Yemen, Rep.  2013   25533217.0
# 246                 Zambia  2013   15246086.0
# 247               Zimbabwe  2013   14898092.0

# %%
popCountries = popReset[34:]
popCountries.head()
# Out:
#            country  year  SP.POP.TOTL
# 34     Afghanistan  2013   30682500.0
# 35         Albania  2013    2897366.0
# 36         Algeria  2013   38186135.0
# 37  American Samoa  2013      55302.0
# 38         Andorra  2013      75902.0

# %% [markdown]
# The actual name of individual countries starts from number 35. Therefore, this removes the data that are not actual countries, and the result contains row 34 onwards.

# %%
popData = popCountries.dropna()
popData.head()
# Out:
#            country  year  SP.POP.TOTL
# 34     Afghanistan  2013   30682500.0
# 35         Albania  2013    2897366.0
# 36         Algeria  2013   38186135.0
# 37  American Samoa  2013      55302.0
# 38         Andorra  2013      75902.0

# %%
COUNTRY = 'country'
headings = [COUNTRY, POP_INDICATOR]
popClean = popData[headings]
popClean.head()
# Out:
#            country  SP.POP.TOTL
# 34     Afghanistan   30682500.0
# 35         Albania    2897366.0
# 36         Algeria   38186135.0
# 37  American Samoa      55302.0
# 38         Andorra      75902.0

# %%
def roundToMillions (value):
    return round(value / 1000000)

# %%
GDP_INDICATOR = 'NY.GDP.MKTP.CD'
gdpReset = pd.read_csv('WB GDP 2013.csv')

LIFE_INDICATOR = 'SP.DYN.LE00.IN'
lifeReset = pd.read_csv('WB LE 2013.csv')

# %%
lifeReset[0:3]
# Out:
#                           country  year  SP.DYN.LE00.IN
# 0                      Arab World  2013       70.631305
# 1          Caribbean small states  2013       71.901964
# 2  Central Europe and the Baltics  2013       76.127583

# %%
lifeReset[240:]
# Out:
#                    country  year  SP.DYN.LE00.IN
# 240                Vanuatu  2013       71.669244
# 241          Venezuela, RB  2013       74.074415
# 242                Vietnam  2013       75.756488
# 243  Virgin Islands (U.S.)  2013       79.624390
# 244     West Bank and Gaza  2013       73.203341
# 245            Yemen, Rep.  2013       63.583512
# 246                 Zambia  2013       59.237366
# 247               Zimbabwe  2013       55.633000

# %%
def roundToMillions(value):

    if pd.isna(value):
        return value
    return round(value / 1000000)

def usdToGBP(usd):
    return usd / 1.564768

GDP = 'GDP (£m)'
gdpReset[GDP] = gdpReset[GDP_INDICATOR].apply(usdToGBP).apply(roundToMillions)
gdpReset.head()
# Out:
#                                    country  year  NY.GDP.MKTP.CD    GDP (£m)
# 0                               Arab World  2013    2.827557e+12   1807014.0
# 1                   Caribbean small states  2013    6.928705e+10     44279.0
# 2           Central Europe and the Baltics  2013    1.419384e+12    907089.0
# 3  East Asia & Pacific (all income levels)  2013    2.084673e+13  13322567.0
# 4    East Asia & Pacific (developing only)  2013    1.172940e+13   7495933.0

# %%
gdpCountries = gdpReset[34:]
lifeCountries = lifeReset[34:]
gdpCountries.head()
# Out:
#            country  year  NY.GDP.MKTP.CD  GDP (£m)
# 34     Afghanistan  2013    2.045894e+10   13075.0
# 35         Albania  2013    1.278103e+10    8168.0
# 36         Algeria  2013    2.097035e+11  134016.0
# 37  American Samoa  2013             NaN       NaN
# 38         Andorra  2013    3.249101e+09    2076.0

# %%
gdpData = gdpCountries.dropna()
lifeData = lifeCountries.dropna()
gdpData.head()
# Out:
#         country  year  NY.GDP.MKTP.CD  GDP (£m)
# 34  Afghanistan  2013    2.045894e+10   13075.0
# 35      Albania  2013    1.278103e+10    8168.0
# 36      Algeria  2013    2.097035e+11  134016.0
# 38      Andorra  2013    3.249101e+09    2076.0
# 39       Angola  2013    1.383568e+11   88420.0

# %%
COUNTRY = 'country'
headings = [COUNTRY, GDP_INDICATOR]
gdpClean = gdpData[headings]
headings = [COUNTRY, LIFE_INDICATOR]
lifeClean = lifeData[headings]
lifeClean.head()
# Out:
#                 country  SP.DYN.LE00.IN
# 34          Afghanistan       60.028268
# 35              Albania       77.537244
# 36              Algeria       74.568951
# 39               Angola       51.866171
# 40  Antigua and Barbuda       75.778659

# %%
gdpVsLifeAll = pd.merge(gdpClean, lifeClean, on=COUNTRY, how='inner')
gdpVsLifeAll.head()
# Out:
#                country  NY.GDP.MKTP.CD  SP.DYN.LE00.IN
# 0          Afghanistan    2.045894e+10       60.028268
# 1              Albania    1.278103e+10       77.537244
# 2              Algeria    2.097035e+11       74.568951
# 3               Angola    1.383568e+11       51.866171
# 4  Antigua and Barbuda    1.200588e+09       75.778659

# %%
GDP = 'GDP (£m)'
column = gdpVsLifeAll[GDP_INDICATOR]
gdpVsLifeAll[GDP] = column.apply(usdToGBP).apply(roundToMillions)
gdpVsLifeAll.head()
# Out:
#                country  NY.GDP.MKTP.CD  SP.DYN.LE00.IN  GDP (£m)
# 0          Afghanistan    2.045894e+10       60.028268     13075
# 1              Albania    1.278103e+10       77.537244      8168
# 2              Algeria    2.097035e+11       74.568951    134016
# 3               Angola    1.383568e+11       51.866171     88420
# 4  Antigua and Barbuda    1.200588e+09       75.778659       767

# %%
LIFE = 'Life expectancy (years)'
gdpVsLifeAll[LIFE] = gdpVsLifeAll[LIFE_INDICATOR].apply(round)
gdpVsLifeAll.head()
# Out:
#                country  NY.GDP.MKTP.CD  SP.DYN.LE00.IN  GDP (£m)  \
# 0          Afghanistan    2.045894e+10       60.028268     13075
# 1              Albania    1.278103e+10       77.537244      8168
# 2              Algeria    2.097035e+11       74.568951    134016
# 3               Angola    1.383568e+11       51.866171     88420
# 4  Antigua and Barbuda    1.200588e+09       75.778659       767
#
#    Life expectancy (years)
# 0                       60
# 1                       78
# 2                       75
# 3                       52
# 4                       76

# %%
headings = [COUNTRY, GDP, LIFE]
gdpVsLifeClean = gdpVsLifeAll[headings]
gdpVsLifeClean.head()
# Out:
#                country  GDP (£m)  Life expectancy (years)
# 0          Afghanistan     13075                       60
# 1              Albania      8168                       78
# 2              Algeria    134016                       75
# 3               Angola     88420                       52
# 4  Antigua and Barbuda       767                       76

# %%
popCleanVsgdpVsLifeClean = pd.merge(gdpVsLifeClean, popClean, on='country', how='right').apply(round)
print(popCleanVsgdpVsLifeClean)
popCleanVsgdpVsLifeClean.to_csv('popCleanVsgdpVsLifeClean.csv')
# Out:
#                    country  GDP (£m)  Life expectancy (years)  SP.POP.TOTL
# 0              Afghanistan   13075.0                     60.0   30682500.0
# 1                  Albania    8168.0                     78.0    2897366.0
# 2                  Algeria  134016.0                     75.0   38186135.0
# 3           American Samoa       NaN                      NaN      55302.0
# 4                  Andorra       NaN                      NaN      75902.0
# ..                     ...       ...                      ...          ...
# 209  Virgin Islands (U.S.)       NaN                      NaN     104737.0
# 210     West Bank and Gaza    7971.0                     73.0    4169506.0
# 211            Yemen, Rep.   22978.0                     64.0   25533217.0
# 212                 Zambia   17140.0                     59.0   15246086.0
# 213               Zimbabwe    8621.0                     56.0   14898092.0
#
# [214 rows x 4 columns]

# %% [markdown]
# ## Provide Notebook-2 Assignment Solutions below (Execute them)

# %%
gdpVspopClean = pd.merge(gdpClean, popClean, on=COUNTRY, how='inner')
gdpVspopClean.head()
# Out:
#        country  NY.GDP.MKTP.CD  SP.POP.TOTL
# 0  Afghanistan    2.045894e+10   30682500.0
# 1      Albania    1.278103e+10    2897366.0
# 2      Algeria    2.097035e+11   38186135.0
# 3      Andorra    3.249101e+09      75902.0
# 4       Angola    1.383568e+11   23448202.0

# %%
from scipy.stats import spearmanr

GDP = 'NY.GDP.MKTP.CD'
POP = 'SP.POP.TOTL'

gdpColumn = gdpVspopClean[GDP]
popColumn = gdpVspopClean[POP]
(correlation, pValue) = spearmanr(gdpColumn, popColumn)
print('The correlation is', correlation)
if pValue < 0.05:
    print('It is statistically significant.')
else:
    print('It is not statistically significant.')
# Out:
# The correlation is 0.7334471556845619
# It is statistically significant.

# %%
# %matplotlib inline
GDP = 'GDP (£m)'
gdpVsLifeClean.plot(x=GDP, y=LIFE, kind='scatter', grid=True)
# Out:
# <Axes: xlabel='GDP (£m)', ylabel='Life expectancy (years)'>

# %%
gdpVsLifeClean.plot(x=LIFE, y=GDP, kind='scatter', grid=True, logx=True, figsize = (10, 4))
# Out:
# <Axes: xlabel='Life expectancy (years)', ylabel='GDP (£m)'>

# %%
GDP = 'NY.GDP.MKTP.CD'
POP = 'SP.POP.TOTL'
gdpVspopClean.plot(x=GDP, y=POP, kind='scatter', grid=True, logx=True, figsize = (10, 4))
# Out:
# <Axes: xlabel='NY.GDP.MKTP.CD', ylabel='SP.POP.TOTL'>

# %%
import matplotlib.pyplot as plt

GDP = 'GDP (£m)'
LIFE = 'Life expectancy (years)'
COUNTRY = 'country'

fig, ax = plt.subplots(figsize=(15, 10))

gdpVsLifeClean.plot(x=GDP, y=LIFE, kind='scatter', grid=True, logx=True, ax=ax)

for i, point in gdpVsLifeClean.iterrows():
    ax.annotate(point[COUNTRY], (point[GDP], point[LIFE]), textcoords="offset points", xytext=(5,5), ha='left', va='center')

plt.title('GDP vs. Life Expectancy with Country Names')
plt.xlabel(GDP)
plt.ylabel(LIFE)
plt.show()

# %%
import matplotlib.pyplot as plt

GDP = 'GDP (£m)'
LIFE = 'Life expectancy (years)'
COUNTRY = 'country'

fig, ax = plt.subplots(figsize=(15, 10))

gdpVsLifeClean.plot(x=GDP, y=LIFE, kind='scatter', grid=True, logx=True, ax=ax)

for i, point in gdpVsLifeClean.iterrows():
    ax.annotate(point[COUNTRY], (point[GDP], point[LIFE]), textcoords="offset points", xytext=(5,5), ha='left', va='center')

plt.title('GDP vs. Life Expectancy with Country Names')
plt.xlabel(GDP)
plt.ylabel(LIFE)
plt.show()

# %%
GDP = 'GDP (£m)'
gdpVsLifeClean.sort_values(GDP).head(10)
# Out:
#                             country  GDP (£m)  Life expectancy (years)
# 87                         Kiribati       108                       66
# 141           Sao Tome and Principe       195                       66
# 111           Micronesia, Fed. Sts.       202                       69
# 168                           Tonga       277                       73
# 37                          Comoros       383                       63
# 157  St. Vincent and the Grenadines       461                       73
# 140                           Samoa       509                       73
# 180                         Vanuatu       512                       72
# 65                          Grenada       538                       73
# 60                      Gambia, The       578                       60

# %%
GDP = 'GDP (£m)'
gdpVsLifeClean.sort_values(GDP, ascending=False).head(10)
# Out:
#                 country  GDP (£m)  Life expectancy (years)
# 177       United States  10715999                       79
# 35                China   6065182                       75
# 83                Japan   3143957                       83
# 62              Germany   2393529                       81
# 58               France   1795953                       82
# 176      United Kingdom   1733354                       81
# 23               Brazil   1528714                       74
# 81                Italy   1363486                       82
# 138  Russian Federation   1328647                       71
# 75                India   1189826                       68

# %%
gdpVsLifeClean.sort_values(LIFE, ascending=False).head(10)
# Out:
#                   country  GDP (£m)  Life expectancy (years)
# 72   Hong Kong SAR, China    176220                       84
# 74                Iceland      9827                       83
# 162           Switzerland    437713                       83
# 83                  Japan   3143957                       83
# 80                 Israel    186870                       82
# 81                  Italy   1363486                       82
# 58                 France   1795953                       82
# 99             Luxembourg     39491                       82
# 7               Australia    999478                       82
# 161                Sweden    369858                       82

# %%
LIFE = 'Life expectancy (years)'
gdpVsLifeClean.sort_values(LIFE, ascending=True).head(10)
# Out:
#                       country  GDP (£m)  Life expectancy (years)
# 95                    Lesotho      1418                       49
# 160                 Swaziland      2916                       49
# 146              Sierra Leone      3092                       50
# 32   Central African Republic       983                       50
# 41              Cote d'Ivoire     19998                       51
# 33                       Chad      8276                       51
# 124                   Nigeria    329100                       52
# 3                      Angola     88420                       52
# 68              Guinea-Bissau       605                       55
# 153               South Sudan      8473                       55

# %% [markdown]
# **To what extent do the ten countries with the highest GDP coincide with the ten countries with the longest life expectancy?**
# Following the data, there is a 30% coincidence. Only three countries, Japan, France, and Italy, appear in the list of the top ten for both GDP and life expectancy. None of the massive economies, for instance, the United States, China, and India, features in the top ten for longevity.

# %% [markdown]
# **Which are the two countries in the right half of the plot (higher GDP) with life expectancy below 60 years?**
#
# Following the right half of the plot, Angola and Nigeria are two countries with life expectancy below 60 years

# %% [markdown]
# **What factors could explain their lower life expectancy compared to countries with similar GDP?**
#
# One of the factors responsible are poor healthcare infrastructure. The quality of healthcare systems put in place for citizens would determine how long they would live. Other countries with better healthcare have higher life expectancies. Other factors, such as political stability and level of education, also affect life expectancy. While political conflict can impact public health infrastructure, health literacy also impacts the overall well-being of citizens.

# %% [markdown]
# # Read and follow the below example analysis

# %% [markdown]
# # GDP and life expectancy
#
# Richer countries can afford to invest more on healthcare, on work and road safety, and other measures that reduce mortality. On the other hand, richer countries may have less healthy lifestyles. Is there any relation between the wealth of a country and the life expectancy of its inhabitants?
#
# The following analysis checks whether there is any correlation between the total gross domestic product (GDP) of a country in 2013 and the life expectancy of people born in that country in 2013.

# %% [markdown]
# ## Getting the data
#
# Two datasets of the World Bank are considered. One dataset, available at <http://data.worldbank.org/indicator/NY.GDP.MKTP.CD>, lists the GDP of the world's countries in current US dollars, for various years. The use of a common currency allows us to compare GDP values across countries. The other dataset, available at <http://data.worldbank.org/indicator/SP.DYN.LE00.IN>, lists the life expectancy of the world's countries. The datasets were downloaded as CSV files in March 2016.

# %%
import warnings
warnings.simplefilter('ignore', FutureWarning)

import pandas as pd

YEAR = 2013
GDP_INDICATOR = 'NY.GDP.MKTP.CD'
gdpReset = pd.read_csv('WB GDP 2013.csv')

LIFE_INDICATOR = 'SP.DYN.LE00.IN'
lifeReset = pd.read_csv('WB LE 2013.csv')
lifeReset.head()
# Out:
#                                    country  year  SP.DYN.LE00.IN
# 0                               Arab World  2013       70.631305
# 1                   Caribbean small states  2013       71.901964
# 2           Central Europe and the Baltics  2013       76.127583
# 3  East Asia & Pacific (all income levels)  2013       74.604619
# 4    East Asia & Pacific (developing only)  2013       73.657617

# %% [markdown]
# ## Cleaning the data
#
# Inspecting the data with `head()` and `tail()` shows that:
#
# 1. the first 34 rows are aggregated data, for the Arab World, the Caribbean small states, and other country groups used by the World Bank;
# - GDP and life expectancy values are missing for some countries.
#
# The data is therefore cleaned by:
# 1. removing the first 34 rows;
# - removing rows with unavailable values.

# %%
gdpCountries = gdpReset[34:].dropna()
lifeCountries = lifeReset[34:].dropna()

# %% [markdown]
# ## Transforming the data
#
# The World Bank reports GDP in US dollars and cents. To make the data easier to read, the GDP is converted to millions of British pounds (the author's local currency) with the following auxiliary functions, using the average 2013 dollar-to-pound conversion rate provided by <http://www.ukforex.co.uk/forex-tools/historical-rate-tools/yearly-average-rates>.

# %%
def roundToMillions (value):
    return round(value / 1000000)

def usdToGBP (usd):
    return usd / 1.564768

GDP = 'GDP (£m)'
gdpCountries[GDP] = gdpCountries[GDP_INDICATOR].apply(usdToGBP).apply(roundToMillions)
gdpCountries.head()
# Out:
#         country  year  NY.GDP.MKTP.CD  GDP (£m)
# 34  Afghanistan  2013    2.045894e+10     13075
# 35      Albania  2013    1.278103e+10      8168
# 36      Algeria  2013    2.097035e+11    134016
# 38      Andorra  2013    3.249101e+09      2076
# 39       Angola  2013    1.383568e+11     88420

# %% [markdown]
# The unnecessary columns can be dropped.

# %%
COUNTRY = 'country'
headings = [COUNTRY, GDP]
gdpClean = gdpCountries[headings]
gdpClean.head()
# Out:
#         country  GDP (£m)
# 34  Afghanistan     13075
# 35      Albania      8168
# 36      Algeria    134016
# 38      Andorra      2076
# 39       Angola     88420

# %% [markdown]
# The World Bank reports the life expectancy with several decimal places. After rounding, the original column is discarded.

# %%
LIFE = 'Life expectancy (years)'
lifeCountries[LIFE] = lifeCountries[LIFE_INDICATOR].apply(round)
headings = [COUNTRY, LIFE]
lifeClean = lifeCountries[headings]
lifeClean.head()
# Out:
#                 country  Life expectancy (years)
# 34          Afghanistan                       60
# 35              Albania                       78
# 36              Algeria                       75
# 39               Angola                       52
# 40  Antigua and Barbuda                       76

# %% [markdown]
# ## Combining the data
#
# The tables are combined through an inner join on the common 'country' column.

# %%
gdpVsLife = merge(gdpClean, lifeClean, on=COUNTRY, how='inner')
gdpVsLife.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3066400265.py in <cell line: 0>()
# ----> 1 gdpVsLife = merge(gdpClean, lifeClean, on=COUNTRY, how='inner')
#       2 gdpVsLife.head()
#
# NameError: name 'merge' is not defined

# %% [markdown]
# ## Calculating the correlation
#
# To measure if the life expectancy and the GDP grow together, the Spearman rank correlation coefficient is used. It is a number from -1 (perfect inverse rank correlation: if one indicator increases, the other decreases) to 1 (perfect direct rank correlation: if one indicator increases, so does the other), with 0 meaning there is no rank correlation. A perfect correlation doesn't imply any cause-effect relation between the two indicators. A p-value below 0.05 means the correlation is statistically significant.

# %%
from scipy.stats import spearmanr

gdpColumn = gdpVsLife[GDP]
lifeColumn = gdpVsLife[LIFE]
(correlation, pValue) = spearmanr(gdpColumn, lifeColumn)
print('The correlation is', correlation)
if pValue < 0.05:
    print('It is statistically significant.')
else:
    print('It is not statistically significant.')
# Out:
# The correlation is 0.35909242322980395
# It is not statistically significant.

# %% [markdown]
# The value shows a direct correlation, i.e. richer countries tend to have longer life expectancy, but it is not very strong.

# %% [markdown]
# ## Showing the data
#
# Measures of correlation can be misleading, so it is best to see the overall picture with a scatterplot. The GDP axis uses a logarithmic scale to better display the vast range of GDP values, from a few million to several billion (million of million) pounds.

# %%
# %matplotlib inline
gdpVsLife.plot(x=GDP, y=LIFE, kind='scatter', grid=True, logx=True, figsize=(10, 4))
# Out:
# <Axes: xlabel='GDP (£m)', ylabel='Life expectancy (years)'>

# %% [markdown]
# The plot shows there is no clear correlation: there are rich countries with low life expectancy, poor countries with high expectancy, and countries with around 10 thousand (10<sup>4</sup>) million pounds GDP have almost the full range of values, from below 50 to over 80 years. Towards the lower and higher end of GDP, the variation diminishes. Above 40 thousand million pounds of GDP (3rd tick mark to the right of 10<sup>4</sup>), most countries have an expectancy of 70 years or more, whilst below that threshold most countries' life expectancy is below 70 years.
#
# Comparing the 10 poorest countries and the 10 countries with the lowest life expectancy shows that total GDP is a rather crude measure. The population size should be taken into account for a more precise definiton of what 'poor' and 'rich' means. Furthermore, looking at the countries below, droughts and internal conflicts may also play a role in life expectancy.

# %%
# the 10 countries with lowest GDP
gdpVsLife.sort_values(GDP).head(10)
# Out:
#     Country name  GDP (£m)  Life expectancy (years)
# 4         Brazil    233937                       75
# 0      Hong Kong    319536                       85
# 3  United States   1435148                       79
# 2      Singapore   5905202                       83
# 1      Australia  10716029                       83

# %%
# the 10 countries with lowest life expectancy
gdpVsLife.sort_values(LIFE).head(10)
# Out:
#     Country name  GDP (£m)  Life expectancy (years)
# 4         Brazil    233937                       75
# 3  United States   1435148                       79
# 2      Singapore   5905202                       83
# 1      Australia  10716029                       83
# 0      Hong Kong    319536                       85

# %% [markdown]
# ## Conclusions
#
# To sum up, there is no strong correlation between a country's wealth and the life expectancy of its inhabitants: there is often a wide variation of life expectancy for countries with similar GDP, countries with the lowest life expectancy are not the poorest countries, and countries with the highest expectancy are not the richest countries. Nevertheless there is some relationship, because the vast majority of countries with a life expectancy below 70 years is on the left half of the scatterplot.
#
# Using the [NY.GDP.PCAP.PP.CD](http://data.worldbank.org/indicator/NY.GDP.PCAP.PP.CD) indicator, GDP per capita in current 'international dollars', would make for a better like-for-like comparison between countries, because it would take population and purchasing power into account. Using more specific data, like expediture on health, could also lead to a better analysis.

# %% [markdown]
# ## Assessment - NOW IS YOUR TURN
#
# **Create your own project**
# Create a completely new project and choose another two of the
# hundreds of World Bank indicators and see if there is any correlation between them. If
# there is a choice of similar indicators, choose one that leads to meaningful
# comparisons between countries.
#
# Look at the results you obtained and take a few moments to assess how they differ.
#
#
# ## GOOD LUCK!

# %%
import pandas as pd

YEAR = 2023
GDP_INDICATOR = 'NY.GDP.MKTP.KD'
GDPReset = pd.read_csv('WB GDP 2023.csv')

MMR_INDICATOR = 'SH.MMR.RISK.ZS'
MMRReset = pd.read_csv('WB MMR 2023.csv')
MMRReset.head()
# Out:
#                   Country Name  Year  SH.MMR.RISK.ZS
# 0                        Aruba  2023        0.000000
# 1  Africa Eastern and Southern  2023        1.201370
# 2                  Afghanistan  2023        2.469342
# 3   Africa Western and Central  2023        2.946454
# 4                       Angola  2023        0.945447

# %%
GDPReset.head()
# Out:
#   Country Name  Year  NY.GDP.MKTP.KD
# 0        Aruba  2023    3.347290e+09
# 1  Afghanistan  2023    1.567265e+10
# 2       Angola  2023    8.579857e+10
# 3      Albania  2023    1.495163e+10
# 4      Andorra  2023    3.252613e+09

# %%
def roundToMillions (value):
    return round(value / 1000000)

def usdToGBP (usd):
    return usd / 1.564768

GDP = 'GDP (£m)'
GDPReset[GDP] = GDPReset[GDP_INDICATOR].apply(usdToGBP).apply(roundToMillions)
GDPReset.head()
# Out:
#   Country Name  Year  NY.GDP.MKTP.KD  GDP (£m)
# 0        Aruba  2023    3.347290e+09      2139
# 1  Afghanistan  2023    1.567265e+10     10016
# 2       Angola  2023    8.579857e+10     54831
# 3      Albania  2023    1.495163e+10      9555
# 4      Andorra  2023    3.252613e+09      2079

# %%
COUNTRY = 'Country Name'
headings = [COUNTRY, GDP]
gdpClean = GDPReset[headings]
gdpClean.head()
# Out:
#   Country Name  GDP (£m)
# 0        Aruba      2139
# 1  Afghanistan     10016
# 2       Angola     54831
# 3      Albania      9555
# 4      Andorra      2079

# %%
MMR = 'Maternal Mortality Rate (%)'
MMRReset[MMR] = MMRReset[MMR_INDICATOR].fillna(0).apply(round)
headings = [COUNTRY, MMR]
MMRClean = MMRReset[headings]
MMRClean.head()
# Out:
#                   Country Name  Maternal Mortality Rate (%)
# 0                        Aruba                            0
# 1  Africa Eastern and Southern                            1
# 2                  Afghanistan                            2
# 3   Africa Western and Central                            3
# 4                       Angola                            1

# %%
gdpVsMMR = pd.merge(gdpClean, MMRClean, on='Country Name', how='inner')
gdpVsMMR.head()
# Out:
#   Country Name  GDP (£m)  Maternal Mortality Rate (%)
# 0        Aruba      2139                            0
# 1  Afghanistan     10016                            2
# 2       Angola     54831                            1
# 3      Albania      9555                            0
# 4      Andorra      2079                            0

# %%
from scipy.stats import spearmanr

gdpColumn = gdpVsMMR[GDP]
mmrColumn = gdpVsMMR[MMR]
(correlation, pValue) = spearmanr(gdpColumn, mmrColumn)
print('The correlation is', correlation)
if pValue < 0.05:
    print('It is statistically significant.')
else:
    print('It is not statistically significant.')
# Out:
# The correlation is -0.21457607983423782
# It is statistically significant.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

gdpVsMMR.plot(x=GDP, y=MMR, kind='scatter', grid=True, logx=True, figsize=(10, 4))
plt.show()

# %%
gdpVsMMR.sort_values(GDP, ascending=False).head(10)
# Out:
#        Country Name  GDP (£m)  Maternal Mortality Rate (%)
# 195   United States  14099584                            0
# 35            China  11255040                            0
# 95            Japan   2940502                            0
# 158      South Asia   2376626                            0
# 48          Germany   2359690                            0
# 86            India   2087031                            0
# 65   United Kingdom   2068259                            0
# 61           France   1707112                            0
# 92            Italy   1287343                            0
# 26           Brazil   1253273                            0

# %%
import matplotlib.pyplot as plt

GDP = 'GDP (£m)'
MMR = 'Maternal Mortality Rate (%)'
COUNTRY = 'Country Name'

fig, ax = plt.subplots(figsize=(15, 10))

gdpVsMMR.plot(x=GDP, y=MMR, kind='scatter', grid=True, logx=True, ax=ax)

for i, point in gdpVsMMR.iterrows():
    ax.annotate(point[COUNTRY], (point[GDP], point[MMR]), textcoords="offset points", xytext=(5,5), ha='left', va='center')

plt.title('GDP vs. Maternal Mortality Rate (%) with Country Names')
plt.xlabel(GDP)
plt.ylabel(MMR)
plt.show()

# %% [markdown]
# **GDP and Maternal Mortality Rate**
#
# Wealthy nations typically have the resources to fund better healthcare systems, workplace safety programs and infrastructure improvements that help save lives. Yet, prosperity can also bring its own health challenges through sedentary lifestyles and other modern afflictions. This raises an interesting question: what's the relationship between a country's economic strength and maternal death rates?
#
# To explore this, data from 2023 were examined, comparing each country's gross domestic product (GDP) against its maternal mortality rate (MMR). The goal was to determine if there's a meaningful connection between national wealth and the likelihood of mothers surviving childbirth.

# %% [markdown]
# **Getting the data**
#
# Two datasets of the World Bank were used for analysis. One dataset, available at http://data.worldbank.org/indicator/NY.GDP.MKTP.CD, lists the GDP of the world's countries in current US dollars, for various years. The common currency being the US dollars allows for comparison across countries. The other dataset, available at http://data.worldbank.org/indicator/SH.MMR.RISK.ZS, lists the maternal mortality rate for different countries. The datasets were downloaded as CSV files in November 2025.[link text](https://)

# %% [markdown]
# **Cleaning the data**
#
# Upon downloading the dataset, cleaning was done majorly with excel to delete the other years that are not of concern in this study. Data cleaning was also initiated to remove non-countries/grouped counties stated in the data. Cells with no values were also replaced with 0 to ensure smooth analysis.
#
# The data was therefore cleaned by:
#
# removing non-countries/grouped counties;
# replacing empty cells with 0.

# %% [markdown]
# **Transforming the data**
#
# While the World Bank reports GDP in US dollars and cents, is it easier to read when the figures are converted to GDP (British pounds). I used the following auxiliary functions, using the average 2013 dollar-to-pound conversion rate provided by http://www.ukforex.co.uk/forex-tools/historical-rate-tools/yearly-average-rates.

# %% [markdown]
# **Combining the data**
#
# The GDP and MMR tables were combined through an inner join on the common 'Country Name' column.

# %% [markdown]
# **Calculating the correlation**
#
# Used the Spearman rank to calculate the correlation coefficient to see the relationship between maternal mortality rate and GDP. This gives a value ranging from -1 to 1. At -1, we have a perfect inverse relationship; when one goes up, the other reliably goes down. At the opposite end, +1 shows they move in lockstep: both climbing or both falling together. A zero means there's no pattern to speak of. However, a perfect correlation doesn't prove one causes the other. And to trust any correlation I find, I need the p-value to come in under 0.05 which is the for statistical significance.
#
# In this case, the correlation was -0.21457607983423782. Therefore, it is statistically significant.

# %% [markdown]
# **Showing the data**
#
# While measures of correlation can be misleading, using a scatterplot gives an overview of the correlation between GDP and MMR. The GDP axis uses a logarithmic scale to better display the vast range of GDP values, from a few million to several billion pounds.
#
# The plot shows that countries with high GDP had mortality rates between 0 and 1 in 2023. On the other hand, countries with lower GDP also recorded between 0 to 1 mortality rate. However, there are outliers like Nigeria with a decent economic flow and high mortality rate compared to other countries like Tuvalu and Nauru with lower GDPs and low mortality rates. Overall, the top 10 countries with high GDP, such as the USA, China, and Japan, amongst others, recorded no mortality rate in the year 2023. Therefore, there is no clear correlation between a country's GDP and maternal death during childbirth. Maternal death rate is a result of the quality of the healthcare system. A country with a high GDP that does not prioritise healthcare would likely have a high maternal mortality rate.

# %% [markdown]
# **Conclusions**
#
# In conclusion, there is no strong correlation between a country's economy and maternal death during childbirth. In 2023, countries with low GDP still recorded low mortality rates, and this is also consistent with countries with high GDP. This contradicts the perception that countries with low GDP are likely to have high mortality rates. However, countries like Nigeria, with a decent GDP, have a high mortality rate, largely due to the country's poor healthcare system. Therefore, GDP does not have any impact on how mothers die during childbirth. It all boils down to how much each country prioritises healthcare systems and how they take bold initiatives to reduce maternal mortality rates. Using healthcare ratings might help to determine the quality of healthcare in each country and its effect on the maternal mortality rate.

# %% [markdown]
# Link to publication - https://datareporting.hashnode.dev/week-8-at-dataraflow-what-happens-when-data-stops-being-abstract
